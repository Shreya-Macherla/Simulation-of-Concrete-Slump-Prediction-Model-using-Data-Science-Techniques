# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
import seaborn as sns

# %%
#df = pd.read_csv(r"C:\Users\mache\Downloads\Programming for Data Analysis\Data set\slump_test.data")
df = pd.read_csv("slump_test.data")
#data filtering
df = df.drop(['No'], axis=1)
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.head()
# Out:
#    Cement   Slag  ...  FLOW(cm)  Compressive Strength (28-day)(Mpa)
# 0   273.0   82.0  ...      62.0                               34.99
# 1   163.0  149.0  ...      20.0                               41.14
# 2   162.0  148.0  ...      20.0                               41.81
# 3   162.0  148.0  ...      21.5                               42.08
# 4   154.0  112.0  ...      64.0                               26.82
#
# [5 rows x 10 columns]

# %%
df.info()
print(df.columns)
print(df.index)
print(df.values)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 10 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Cement                              103 non-null    float64
#  1   Slag                                103 non-null    float64
#  2   Fly ash                             103 non-null    float64
#  3   Water                               103 non-null    float64
#  4   SP                                  103 non-null    float64
#  5   Coarse Aggr.                        103 non-null    float64
#  6   Fine Aggr.                          103 non-null    float64
#  7   SLUMP(cm)                           103 non-null    float64
#  8   FLOW(cm)                            103 non-null    float64
#  9   Compressive Strength (28-day)(Mpa)  103 non-null    float64
# dtypes: float64(10)
# memory usage: 8.2 KB
# Index(['Cement', 'Slag', 'Fly ash', 'Water', 'SP', 'Coarse Aggr.',
#        'Fine Aggr.', 'SLUMP(cm)', 'FLOW(cm)',
#        'Compressive Strength (28-day)(Mpa)'],
#       dtype='object')
# RangeIndex(start=0, stop=103, step=1)
# [[2.730e+02 8.200e+01 1.050e+02 ... 2.300e+01 6.200e+01 3.499e+01]
#  [1.630e+02 1.490e+02 1.910e+02 ... 0.000e+00 2.000e+01 4.114e+01]
#  [1.620e+02 1.480e+02 1.910e+02 ... 1.000e+00 2.000e+01 4.181e+01]
#  ...
#  [2.588e+02 8.800e+01 2.396e+02 ... 0.000e+00 2.000e+01 5.050e+01]
#  [2.971e+02 4.090e+01 2.399e+02 ... 2.750e+01 6.700e+01 4.917e+01]
#  [3.487e+02 1.000e-01 2.231e+02 ... 2.900e+01 7.800e+01 4.877e+01]]

# %%
# Data Cleaning
df.isnull()
# Out:
#      Cement   Slag  ...  FLOW(cm)  Compressive Strength (28-day)(Mpa)
# 0     False  False  ...     False                               False
# 1     False  False  ...     False                               False
# 2     False  False  ...     False                               False
# 3     False  False  ...     False                               False
# 4     False  False  ...     False                               False
# ..      ...    ...  ...       ...                                 ...
# 98    False  False  ...     False                               False
# 99    False  False  ...     False                               False
# 100   False  False  ...     False                               False
# 101   False  False  ...     False                               False
# 102   False  False  ...     False                               False
#
# [103 rows x 10 columns]

# %%
# checked for null values
df.isnull().sum()
# Out:
# Cement                                0
# Slag                                  0
# Fly ash                               0
# Water                                 0
# SP                                    0
# Coarse Aggr.                          0
# Fine Aggr.                            0
# SLUMP(cm)                             0
# FLOW(cm)                              0
# Compressive Strength (28-day)(Mpa)    0
# dtype: int64

# %%
# Descriptive statistics for each column
df.describe()
# Out:
#            Cement        Slag  ...   FLOW(cm)  Compressive Strength (28-day)(Mpa)
# count  103.000000  103.000000  ...  103.00000                          103.000000
# mean   229.894175   77.973786  ...   49.61068                           36.039417
# std     78.877230   60.461363  ...   17.56861                            7.838232
# min    137.000000    0.000000  ...   20.00000                           17.190000
# 25%    152.000000    0.050000  ...   38.50000                           30.900000
# 50%    248.000000  100.000000  ...   54.00000                           35.520000
# 75%    303.900000  125.000000  ...   63.75000                           41.205000
# max    374.000000  193.000000  ...   78.00000                           58.530000
#
# [8 rows x 10 columns]

# %%
#drops rows with missing values
df = df.dropna(axis=0)
df
# Out:
#      Cement   Slag  ...  FLOW(cm)  Compressive Strength (28-day)(Mpa)
# 0     273.0   82.0  ...      62.0                               34.99
# 1     163.0  149.0  ...      20.0                               41.14
# 2     162.0  148.0  ...      20.0                               41.81
# 3     162.0  148.0  ...      21.5                               42.08
# 4     154.0  112.0  ...      64.0                               26.82
# ..      ...    ...  ...       ...                                 ...
# 98    248.3  101.0  ...      20.0                               49.97
# 99    248.0  101.0  ...      20.0                               50.23
# 100   258.8   88.0  ...      20.0                               50.50
# 101   297.1   40.9  ...      67.0                               49.17
# 102   348.7    0.1  ...      78.0                               48.77
#
# [103 rows x 10 columns]

# %%
df.shape
# Out:
# (103, 10)

# %%
print (df.describe())
df.boxplot()
df.hist()
# Out:
#            Cement        Slag  ...   FLOW(cm)  Compressive Strength (28-day)(Mpa)
# count  103.000000  103.000000  ...  103.00000                          103.000000
# mean   229.894175   77.973786  ...   49.61068                           36.039417
# std     78.877230   60.461363  ...   17.56861                            7.838232
# min    137.000000    0.000000  ...   20.00000                           17.190000
# 25%    152.000000    0.050000  ...   38.50000                           30.900000
# 50%    248.000000  100.000000  ...   54.00000                           35.520000
# 75%    303.900000  125.000000  ...   63.75000                           41.205000
# max    374.000000  193.000000  ...   78.00000                           58.530000
#
# [8 rows x 10 columns]
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd9b61106d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd9b6020750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd9b5fd6c50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd9b5f98310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd9b5f4d990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd9b5f83fd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd9b5f45750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd9b5ef9d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd9b5ef9d50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd9b5ebe510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd9b5e1fb90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd9b5de9710>]],
#       dtype=object)

# %%
# Data Exploration
print(df.corr())
correlationMatrix=df.corr(method='spearman')
ax = sns.heatmap(correlationMatrix, vmin=-1, vmax=1, center=0, cmap=sns.diverging_palette(0, 250, n=50), square=True)
ax.set_xticklabels(ax.get_xticklabels(), rotation=50, horizontalalignment='right');
# Out:
#                                       Cement  ...  Compressive Strength (28-day)(Mpa)
# Cement                              1.000000  ...                            0.445725
# Slag                               -0.243553  ...                           -0.331588
# Fly ash                            -0.486535  ...                            0.444393
# Water                               0.221091  ...                           -0.254235
# SP                                 -0.106387  ...                           -0.037871
# Coarse Aggr.                       -0.309857  ...                           -0.160684
# Fine Aggr.                          0.056959  ...                           -0.154484
# SLUMP(cm)                           0.145913  ...                           -0.223358
# FLOW(cm)                            0.186461  ...                           -0.124029
# Compressive Strength (28-day)(Mpa)  0.445725  ...                            1.000000
#
# [10 rows x 10 columns]

# %%
# Data Exploration
sns.pairplot(df)

# %%
sns.heatmap(df.corr(), annot=True, cmap='Blues')

# %%
def rmse(targets, predictions):
    return np.sqrt(((predictions - targets) ** 2).mean())

# %%
#feature selection
input_variables = ['Cement','Slag','Fly ash','Water','SP','Coarse Aggr.','Fine Aggr.']
output_variables = ['SLUMP(cm)','FLOW(cm)','Compressive Strength (28-day)(Mpa)']
x = df[input_variables]
y = df[output_variables]

# %%
#coverting to numpy array
x=np.array(x)
y=np.array(y)

# %%
#data splitting
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# %% [markdown]
# # Simple Linear Regression

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.coef_
# Out:
# array([[-0.00592405, -0.02952231, -0.01103637,  0.18180433, -0.41724627,
#          0.00219104,  0.01452085],
#        [ 0.03102915, -0.00559832,  0.04749536,  0.66095941, -0.06861753,
#          0.04350386,  0.06826942],
#        [ 0.05896049, -0.03041615,  0.05162036, -0.21599926,  0.18102602,
#         -0.05429132, -0.04161727]])

# %%
y_pred = reg.predict(X_test)

# %%
print(f'The R2 score is: {r2_score(y_test, y_pred)}')
print(f'The RMSE score is {rmse(y_test, y_pred)}')
# Out:
# The R2 score is: 0.5643927006516468
# The RMSE score is 8.527237043240973

# %%
y_pred = reg.predict(X_test)
#print(f'The R2 score is: {r2_score(Y_test, y_pred)}')
#print(f'The RMSE score is {rmse(Y_test, y_pred)}')
print("Making predictions for the following in train set:")
predicted_values=reg.predict(X_train[0:4,:])
true_values=y_train[0:4]
print("True values are ",true_values)
print("The predicted values are", predicted_values)
print("Diff", predicted_values-true_values)


print("Making predictions for the following in testing set:")
predicted_values=reg.predict(X_test[0:4,:])
true_values=y_test[0:4]
print("True values are ",true_values)
print("The predicted values are", predicted_values)
print("Diff", predicted_values-true_values)
# Out:
# Making predictions for the following in train set:
# True values are  [[21.   64.   26.28]
#  [24.   75.   36.19]
#  [26.5  68.   35.52]
#  [22.   40.   31.5 ]]
# The predicted values are [[22.31928568 59.67794673 28.87500627]
#  [27.02302355 78.02000351 32.83274424]
#  [19.2134511  52.39144804 38.94097458]
#  [16.3038782  41.25014511 32.00863516]]
# Diff [[  1.31928568  -4.32205327   2.59500627]
#  [  3.02302355   3.02000351  -3.35725576]
#  [ -7.2865489  -15.60855196   3.42097458]
#  [ -5.6961218    1.25014511   0.50863516]]
# Making predictions for the following in testing set:
# True values are  [[25.   63.   28.29]
#  [ 2.5  20.   35.66]
#  [21.   57.   33.78]
#  [26.   64.   31.9 ]]
# The predicted values are [[19.91691753 52.53287723 29.17326113]
#  [14.94008223 49.75429429 38.33116142]
#  [14.99618534 43.26408336 37.50212509]
#  [23.08725778 59.16511701 32.25595834]]
# Diff [[ -5.08308247 -10.46712277   0.88326113]
#  [ 12.44008223  29.75429429   2.67116142]
#  [ -6.00381466 -13.73591664   3.72212509]
#  [ -2.91274222  -4.83488299   0.35595834]]

# %%
# Average training error
dfTrain=y_train-reg.predict(X_train)
print("Average Train error ", np.absolute(dfTrain).min())

# Average test error
dfTest=y_test-reg.predict(X_test)
print("Average test error ", np.absolute(dfTest).min())
# Out:
# Average Train error  0.016001258209584535
# Average test error  0.0983087391804176

# %%
plt.scatter(y_train, reg.predict(X_train))
plt.title('Predictions vs True Values (Training)')
plt.xlabel('True Values')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
plt.scatter(y_test, reg.predict(X_test))
plt.title('Predictions vs True Values (Test)')
plt.xlabel('True Values')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
y_train
# Out:
# array([[21.  , 64.  , 26.28],
#        [24.  , 75.  , 36.19],
#        [26.5 , 68.  , 35.52],
#        [22.  , 40.  , 31.5 ],
#        [21.25, 46.  , 36.32],
#        [23.  , 50.  , 19.19],
#        [18.  , 48.  , 37.66],
#        [25.75, 64.5 , 43.54],
#        [24.5 , 61.  , 26.02],
#        [ 1.  , 20.  , 41.81],
#        [25.5 , 64.  , 37.39],
#        [27.5 , 64.  , 39.13],
#        [15.  , 48.5 , 29.23],
#        [26.5 , 70.  , 39.4 ],
#        [13.  , 38.  , 33.51],
#        [24.  , 65.  , 29.5 ],
#        [23.  , 63.5 , 34.18],
#        [24.  , 47.  , 41.27],
#        [ 3.  , 20.  , 30.97],
#        [24.  , 62.  , 38.59],
#        [25.  , 78.  , 44.48],
#        [18.  , 46.  , 17.19],
#        [27.5 , 70.  , 34.45],
#        [14.5 , 36.5 , 38.19],
#        [25.  , 69.  , 26.42],
#        [ 0.  , 20.  , 44.08],
#        [23.5 , 54.5 , 34.05],
#        [25.  , 55.  , 27.09],
#        [23.  , 65.  , 33.51],
#        [17.5 , 48.  , 31.77],
#        [ 0.  , 20.  , 41.81],
#        [ 8.  , 30.  , 36.46],
#        [25.  , 70.  , 42.08],
#        [27.5 , 67.  , 49.17],
#        [24.  , 59.  , 27.62],
#        [24.  , 67.  , 27.89],
#        [ 0.  , 20.  , 36.72],
#        [20.  , 64.  , 26.82],
#        [ 0.  , 20.  , 41.01],
#        [ 0.  , 20.  , 50.5 ],
#        [21.5 , 42.  , 52.65],
#        [13.  , 46.  , 36.19],
#        [14.5 , 41.5 , 35.52],
#        [ 3.  , 21.5 , 42.08],
#        [24.  , 60.  , 45.82],
#        [25.  , 61.  , 43.01],
#        [16.25, 31.  , 30.83],
#        [15.5 , 51.  , 32.71],
#        [19.  , 48.  , 32.71],
#        [23.  , 62.  , 34.99],
#        [ 0.  , 20.  , 41.54],
#        [22.  , 49.  , 29.63],
#        [ 0.  , 20.  , 18.52],
#        [22.5 , 48.5 , 39.93],
#        [23.  , 69.  , 30.43],
#        [14.5 , 58.5 , 36.59],
#        [ 2.  , 20.  , 50.23],
#        [17.  , 54.  , 33.91],
#        [ 2.  , 20.  , 46.36],
#        [ 9.5 , 27.5 , 37.92],
#        [14.5 , 42.5 , 32.44],
#        [21.5 , 64.  , 41.14],
#        [16.  , 26.  , 41.27],
#        [23.75, 58.  , 28.03],
#        [23.5 , 52.5 , 33.78],
#        [20.5 , 48.2 , 49.3 ],
#        [20.  , 49.  , 29.77],
#        [23.5 , 60.  , 45.69],
#        [23.75, 53.  , 33.38],
#        [ 0.  , 20.  , 38.86],
#        [23.  , 58.  , 28.16],
#        [12.  , 39.  , 32.57],
#        [ 0.  , 20.  , 41.14],
#        [12.  , 35.  , 28.29],
#        [27.  , 60.  , 37.39],
#        [23.5 , 53.  , 30.43],
#        [23.  , 55.  , 25.21],
#        [23.5 , 58.5 , 28.7 ],
#        [19.  , 51.  , 38.46],
#        [25.5 , 67.  , 29.77],
#        [25.5 , 67.  , 31.37],
#        [14.5 , 20.  , 18.26]])

# %% [markdown]
# # Multiple Linear Regression

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train, y_train)
y_pred = reg.predict(X_test)

# %%
print(f'The R2 score is: {r2_score(y_test, y_pred)}')
print(f'The RMSE score is {rmse(y_test, y_pred)}')
# Out:
# The R2 score is: 0.5643927006516468
# The RMSE score is 8.527237043240973

# %%
reg.coef_
# Out:
# array([[-0.00592405, -0.02952231, -0.01103637,  0.18180433, -0.41724627,
#          0.00219104,  0.01452085],
#        [ 0.03102915, -0.00559832,  0.04749536,  0.66095941, -0.06861753,
#          0.04350386,  0.06826942],
#        [ 0.05896049, -0.03041615,  0.05162036, -0.21599926,  0.18102602,
#         -0.05429132, -0.04161727]])

# %%
y_pred = reg.predict(X_test)
#print(f'The R2 score is: {r2_score(Y_test, y_pred)}')
#print(f'The RMSE score is {rmse(Y_test, y_pred)}')
print("Making predictions for the following in train set:")
predicted_values=reg.predict(X_train[0:4,:])
true_values=y_train[0:4]
print("True values are ",true_values)
print("The predicted values are", predicted_values)
print("Diff", predicted_values-true_values)


print("Making predictions for the following in testing set:")
predicted_values=reg.predict(X_test[0:4,:])
true_values=y_test[0:4]
print("True values are ",true_values)
print("The predicted values are", predicted_values)
print("Diff", predicted_values-true_values)
# Out:
# Making predictions for the following in train set:
# True values are  [[21.   64.   26.28]
#  [24.   75.   36.19]
#  [26.5  68.   35.52]
#  [22.   40.   31.5 ]]
# The predicted values are [[22.31928568 59.67794673 28.87500627]
#  [27.02302355 78.02000351 32.83274424]
#  [19.2134511  52.39144804 38.94097458]
#  [16.3038782  41.25014511 32.00863516]]
# Diff [[  1.31928568  -4.32205327   2.59500627]
#  [  3.02302355   3.02000351  -3.35725576]
#  [ -7.2865489  -15.60855196   3.42097458]
#  [ -5.6961218    1.25014511   0.50863516]]
# Making predictions for the following in testing set:
# True values are  [[25.   63.   28.29]
#  [ 2.5  20.   35.66]
#  [21.   57.   33.78]
#  [26.   64.   31.9 ]]
# The predicted values are [[19.91691753 52.53287723 29.17326113]
#  [14.94008223 49.75429429 38.33116142]
#  [14.99618534 43.26408336 37.50212509]
#  [23.08725778 59.16511701 32.25595834]]
# Diff [[ -5.08308247 -10.46712277   0.88326113]
#  [ 12.44008223  29.75429429   2.67116142]
#  [ -6.00381466 -13.73591664   3.72212509]
#  [ -2.91274222  -4.83488299   0.35595834]]

# %%
# Average training error
dfTrain=y_train-reg.predict(X_train)
print("Average Train error ", np.absolute(dfTrain).mean())

# Average test error
dfTest=y_test-reg.predict(X_test)
print("Average test error ", np.absolute(dfTest).mean())
# Out:
# Average Train error  6.109757046777961
# Average test error  6.158789860795649

# %%
plt.scatter(y_train, reg.predict(X_train))
plt.title('Predictions vs True Values (Training)')
plt.xlabel('True Values')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
plt.scatter(y_test, reg.predict(X_test))
plt.title('Predictions vs True Values (Test)')
plt.xlabel('True Values')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %% [markdown]
# # Polynomial Regression

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(x)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg_2.coef_
# Out:
# array([[ 1.32882501e-18, -4.45344350e-14, -1.95119524e-15,
#          5.04542856e-15,  1.46964313e-14,  3.21634001e-16,
#         -5.53963021e-14,  5.00259473e-14, -1.42343875e-11,
#         -1.12627183e-12, -5.61771743e-12, -4.36505300e-12,
#         -4.24466989e-13, -3.10521822e-11, -1.56349010e-11,
#          1.33682524e-13, -7.15959986e-13,  4.69734217e-13,
#         -4.83680448e-14, -4.03039097e-12,  1.06936802e-12,
#          3.87605109e-12,  2.62599304e-12, -7.90242884e-13,
#         -4.85674902e-12,  8.64657066e-12,  4.28196228e-12,
#         -3.22526175e-13,  7.45124278e-13,  1.39262964e-11,
#         -1.15789485e-14,  5.10607066e-13,  8.67828178e-13,
#         -6.35955705e-11,  6.83520503e-13,  5.08186034e-11,
#         -2.86196860e-09, -8.35846656e-11, -1.25521472e-09,
#         -1.24011994e-09, -5.84010630e-11, -6.24473212e-09,
#         -5.07747730e-09, -2.88284802e-11, -2.27846835e-10,
#          7.45253000e-11,  1.64807025e-11, -1.02277370e-09,
#         -6.68333845e-12, -7.32555417e-10, -6.10894623e-10,
#         -7.46693516e-12, -2.58067294e-09, -1.56418891e-09,
#         -1.96071816e-10, -4.81234448e-10, -2.27872625e-09,
#         -1.12521756e-09,  1.90696987e-10, -4.46810765e-12,
#         -1.17440528e-10, -1.60395183e-08, -8.97157109e-09,
#         -2.98691195e-09,  1.52938054e-10, -9.73123712e-11,
#          1.24542492e-10, -1.84141246e-10, -2.37274827e-10,
#          1.46316299e-11,  2.70867136e-10,  5.87010329e-11,
#         -2.48600163e-10, -8.55964274e-10,  3.28387693e-11,
#          1.44336624e-10,  1.65571204e-10, -2.11534721e-10,
#          3.26071108e-10, -1.56119909e-10, -4.66943558e-11,
#          1.14795655e-10, -2.90475710e-09, -1.28524176e-10,
#          8.05502369e-10,  5.63085749e-10,  7.37982061e-10,
#         -3.42801768e-11,  1.07368659e-09,  1.84031025e-09,
#          5.61784630e-10, -4.97489990e-10,  3.84275577e-10,
#          1.43896784e-09, -8.85643566e-11, -2.48199483e-10,
#         -3.25442511e-10, -5.63661284e-09,  8.18269165e-10,
#          5.90310635e-09,  9.42006749e-10, -2.11242427e-10,
#          9.63956323e-10,  2.00595299e-09,  1.31075754e-11,
#          2.82624416e-11, -7.59812556e-11, -2.90781269e-09,
#          8.31383004e-10,  3.56923571e-09,  2.34211977e-09,
#          1.09173007e-08,  2.57614227e-09, -6.15054353e-09,
#         -1.75517824e-10,  3.21828645e-10, -2.76403285e-09,
#          1.75883442e-09, -2.21241728e-08, -4.76516606e-11,
#          1.59073055e-08,  5.61945244e-08, -1.26303370e-09,
#         -1.20441350e-09,  1.71083187e-09, -7.31639105e-09,
#         -3.95286599e-09, -1.29755677e-08,  5.50899643e-10,
#         -4.90091666e-09, -5.08491760e-09,  3.95023954e-09,
#         -3.65555824e-09,  2.26892337e-09,  2.21972802e-09,
#         -5.07081979e-09,  7.41183211e-09, -1.95470062e-09,
#          1.57136543e-10,  2.73328131e-09,  2.26743512e-09,
#         -1.81239171e-08, -1.95315665e-08, -2.08255261e-08,
#         -7.11373362e-09,  1.21745075e-08,  9.02390662e-10,
#         -5.70818192e-09, -1.66993306e-10,  1.63796587e-09,
#         -3.08667583e-09,  2.19591606e-09, -6.11995587e-10]])

# %%
y_pred = lin_reg.predict(X_test)
#print(f'The R2 score is: {r2_score(Y_test, y_pred)}')
#print(f'The RMSE score is {rmse(Y_test, y_pred)}')
print("Making predictions for the following in train set:")
predicted_values=lin_reg.predict(X_train[0:4,:])
true_values=y_train[0:4]
print("True values are ",true_values)
print("The predicted values are", predicted_values)
print("Diff", predicted_values-true_values)


print("Making predictions for the following in testing set:")
predicted_values=lin_reg.predict(X_test[0:4,:])
true_values=y_test[0:4]
print("True values are ",true_values)
print("The predicted values are", predicted_values)
print("Diff", predicted_values-true_values)
# Out:
# Making predictions for the following in train set:
# True values are  [[21.   64.   26.28]
#  [24.   75.   36.19]
#  [26.5  68.   35.52]
#  [22.   40.   31.5 ]]
# The predicted values are [[23.80679649 61.41794035 28.10131028]
#  [29.04730197 80.619458   32.03884225]
#  [18.96842452 52.51794441 39.16085388]
#  [16.69198658 42.7729185  32.23931558]]
# Diff [[  2.80679649  -2.58205965   1.82131028]
#  [  5.04730197   5.619458    -4.15115775]
#  [ -7.53157548 -15.48205559   3.64085388]
#  [ -5.30801342   2.7729185    0.73931558]]
# Making predictions for the following in testing set:
# True values are  [[25.   63.   28.29]
#  [ 2.5  20.   35.66]
#  [21.   57.   33.78]
#  [26.   64.   31.9 ]]
# The predicted values are [[20.63215766 54.15409219 29.01149131]
#  [14.11665843 46.61984953 37.62727798]
#  [16.48536845 46.26333234 36.76419692]
#  [22.40707586 58.31471284 32.58796099]]
# Diff [[ -4.36784234  -8.84590781   0.72149131]
#  [ 11.61665843  26.61984953   1.96727798]
#  [ -4.51463155 -10.73666766   2.98419692]
#  [ -3.59292414  -5.68528716   0.68796099]]

# %%
print(f'The R2 score is: {r2_score(y, lin_reg_2.predict(X_poly))}')
print(f'The RMSE score is {rmse(y, lin_reg_2.predict(X_poly))}')
# Out:
# The R2 score is: 1.0
# The RMSE score is 6.170441290005409e-11

# %%
# Average training error
dfTrain=y_train-lin_reg.predict(X_train)
print("Average Train error ", np.absolute(dfTrain).mean())

# Average test error
dfTest=y_test-lin_reg.predict(X_test)
print("Average test error ", np.absolute(dfTest).mean())
# Out:
# Average Train error  6.194509502892696
# Average test error  5.588689869049075

# %%
plt.scatter(y_train, lin_reg.predict(X_train))
plt.title('Predictions vs True Values (Training)')
plt.xlabel('True Values')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
plt.scatter(y_test, lin_reg.predict(X_test))
plt.title('Predictions vs True Values (Test)')
plt.xlabel('True Values')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Ridge
reg = Ridge()
reg.fit(X_train, y_train)
y_pred = reg.predict(X_test)

# %%
print(f'The R2 score is: {r2_score(y_test, y_pred)}')
print(f'The RMSE score is {rmse(y_test, y_pred)}')
# Out:
# The R2 score is: 0.5644515817612394
# The RMSE score is 8.527044953228641

# %%
reg.coef_
# Out:
# array([[-0.00578803, -0.02934637, -0.01089579,  0.18225144, -0.41597802,
#          0.00235305,  0.01468771],
#        [ 0.03078492, -0.0059412 ,  0.0472456 ,  0.66015622, -0.0695131 ,
#          0.04320949,  0.06796088],
#        [ 0.05896128, -0.03040871,  0.05162059, -0.21599597,  0.18072219,
#         -0.05428928, -0.04161398]])

# %%
y_pred = reg.predict(X_test)
#print(f'The R2 score is: {r2_score(Y_test, y_pred)}')
#print(f'The RMSE score is {rmse(Y_test, y_pred)}')
print("Making predictions for the following in train set:")
predicted_values=reg.predict(X_train[0:4,:])
true_values=y_train[0:4]
print("True values are ",true_values)
print("The predicted values are", predicted_values)
print("Diff", predicted_values-true_values)


print("Making predictions for the following in testing set:")
predicted_values=reg.predict(X_test[0:4,:])
true_values=y_test[0:4]
print("True values are ",true_values)
print("The predicted values are", predicted_values)
print("Diff", predicted_values-true_values)
# Out:
# Making predictions for the following in train set:
# True values are  [[21.   64.   26.28]
#  [24.   75.   36.19]
#  [26.5  68.   35.52]
#  [22.   40.   31.5 ]]
# The predicted values are [[22.31946723 59.67482369 28.87564611]
#  [27.03019668 78.01003633 32.83212192]
#  [19.21388078 52.39080055 38.94093907]
#  [16.30492525 41.24895146 32.0085015 ]]
# Diff [[  1.31946723  -4.32517631   2.59564611]
#  [  3.03019668   3.01003633  -3.35787808]
#  [ -7.28611922 -15.60919945   3.42093907]
#  [ -5.69507475   1.24895146   0.5085015 ]]
# Making predictions for the following in testing set:
# True values are  [[25.   63.   28.29]
#  [ 2.5  20.   35.66]
#  [21.   57.   33.78]
#  [26.   64.   31.9 ]]
# The predicted values are [[19.9186745  52.53074067 29.17305492]
#  [14.94003658 49.75621087 38.33073764]
#  [14.99668369 43.26906252 37.50079787]
#  [23.08584735 59.16246813 32.25711937]]
# Diff [[ -5.0813255  -10.46925933   0.88305492]
#  [ 12.44003658  29.75621087   2.67073764]
#  [ -6.00331631 -13.73093748   3.72079787]
#  [ -2.91415265  -4.83753187   0.35711937]]

# %%
# Average training error
dfTrain=y_train-reg.predict(X_train)
print("Average Train error ", np.absolute(dfTrain).mean())

# Average test error
dfTest=y_test-reg.predict(X_test)
print("Average test error ", np.absolute(dfTest).mean())
# Out:
# Average Train error  6.109870804827702
# Average test error  6.158945598544357

# %%
plt.scatter(y_train, reg.predict(X_train))
plt.title('Predictions vs True Values (Training)')
plt.xlabel('True Values')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
plt.scatter(y_test, reg.predict(X_test))
plt.title('Predictions vs True Values (Test)')
plt.xlabel('True Values')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso
reg = Lasso(alpha=1.2)
reg.fit(X_train, y_train)
y_pred = reg.predict(X_test)

# %%
print(f'The R2 score is: {r2_score(y_test, y_pred)}')
print(f'The RMSE score is {rmse(y_test, y_pred)}')
# Out:
# The R2 score is: 0.5770122972254893
# The RMSE score is 8.440245146004665

# %%
reg.coef_
# Out:
# array([[ 0.        , -0.02429258, -0.00450821,  0.20087781, -0.22796316,
#          0.00855499,  0.02054436],
#        [ 0.00352102, -0.04650845,  0.01985529,  0.57497025, -0.01279823,
#          0.01056217,  0.03273901],
#        [ 0.07098204, -0.00972278,  0.06352986, -0.17739992,  0.0580943 ,
#         -0.03905203, -0.02480339]])

# %%
y_pred = reg.predict(X_test)
#print(f'The R2 score is: {r2_score(Y_test, y_pred)}')
#print(f'The RMSE score is {rmse(Y_test, y_pred)}')
print("Making predictions for the following in train set:")
predicted_values=reg.predict(X_train[0:4,:])
true_values=y_train[0:4]
print("True values are ",true_values)
print("The predicted values are", predicted_values)
print("Diff", predicted_values-true_values)


print("Making predictions for the following in testing set:")
predicted_values=reg.predict(X_test[0:4,:])
true_values=y_test[0:4]
print("True values are ",true_values)
print("The predicted values are", predicted_values)
print("Diff", predicted_values-true_values)
# Out:
# Making predictions for the following in train set:
# True values are  [[21.   64.   26.28]
#  [24.   75.   36.19]
#  [26.5  68.   35.52]
#  [22.   40.   31.5 ]]
# The predicted values are [[22.024281   59.08729256 29.32346819]
#  [27.60258648 77.3065848  32.9027199 ]
#  [19.25141756 52.29707515 38.96218395]
#  [16.38706586 41.16751797 32.03403846]]
# Diff [[  1.024281    -4.91270744   3.04346819]
#  [  3.60258648   2.3065848   -3.2872801 ]
#  [ -7.24858244 -15.70292485   3.44218395]
#  [ -5.61293414   1.16751797   0.53403846]]
# Making predictions for the following in testing set:
# True values are  [[25.   63.   28.29]
#  [ 2.5  20.   35.66]
#  [21.   57.   33.78]
#  [26.   64.   31.9 ]]
# The predicted values are [[20.07072568 52.45554033 29.16421661]
#  [15.1981153  50.23240416 37.99097301]
#  [15.56090667 44.44190099 36.53139377]
#  [22.53070219 58.33569271 33.00662183]]
# Diff [[ -4.92927432 -10.54445967   0.87421661]
#  [ 12.6981153   30.23240416   2.33097301]
#  [ -5.43909333 -12.55809901   2.75139377]
#  [ -3.46929781  -5.66430729   1.10662183]]

# %%
# Average training error
dfTrain=y_train-reg.predict(X_train)
print("Average Train error ", np.absolute(dfTrain).mean())

# Average test error
dfTest=y_test-reg.predict(X_test)
print("Average test error ", np.absolute(dfTest).mean())
# Out:
# Average Train error  6.155343261141109
# Average test error  6.087856157088196

# %%
plt.scatter(y_train, reg.predict(X_train))
plt.title('Predictions vs True Values (Training)')
plt.xlabel('True Values')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
plt.scatter(y_test, reg.predict(X_test))
plt.title('Predictions vs True Values (Test)')
plt.xlabel('True Values')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %% [markdown]
# # Elastic Net Regression

# %%
from sklearn.linear_model import ElasticNet
reg = ElasticNet()
reg.fit(X_train, y_train)
y_pred = reg.predict(X_test)

# %%
print(f'The R2 score is: {r2_score(y_test, y_pred)}')
print(f'The RMSE score is {rmse(y_test, y_pred)}')
# Out:
# The R2 score is: 0.5716043901398664
# The RMSE score is 8.48415846512009

# %%
reg.coef_
# Out:
# array([[ 0.        , -0.02295186, -0.00475   ,  0.2009939 , -0.30314637,
#          0.0089258 ,  0.02122985],
#        [ 0.01128731, -0.03429174,  0.02751031,  0.59783312, -0.07465575,
#          0.0197864 ,  0.0429943 ],
#        [ 0.06483119, -0.02040956,  0.0574483 , -0.19705036,  0.12469404,
#         -0.04686877, -0.03345781]])

# %%
y_pred = reg.predict(X_test)
#print(f'The R2 score is: {r2_score(Y_test, y_pred)}')
#print(f'The RMSE score is {rmse(Y_test, y_pred)}')
print("Making predictions for the following in train set:")
predicted_values=reg.predict(X_train[0:4,:])
true_values=y_train[0:4]
print("True values are ",true_values)
print("The predicted values are", predicted_values)
print("Diff", predicted_values-true_values)


print("Making predictions for the following in testing set:")
predicted_values=reg.predict(X_test[0:4,:])
true_values=y_test[0:4]
print("True values are ",true_values)
print("The predicted values are", predicted_values)
print("Diff", predicted_values-true_values)
# Out:
# Making predictions for the following in train set:
# True values are  [[21.   64.   26.28]
#  [24.   75.   36.19]
#  [26.5  68.   35.52]
#  [22.   40.   31.5 ]]
# The predicted values are [[22.19185754 59.32197704 29.09017369]
#  [27.44994832 77.38513678 32.87941646]
#  [19.24148133 52.33083399 38.95085545]
#  [16.36766585 41.17639871 32.01989033]]
# Diff [[  1.19185754  -4.67802296   2.81017369]
#  [  3.44994832   2.38513678  -3.31058354]
#  [ -7.25851867 -15.66916601   3.43085545]
#  [ -5.63233415   1.17639871   0.51989033]]
# Making predictions for the following in testing set:
# True values are  [[25.   63.   28.29]
#  [ 2.5  20.   35.66]
#  [21.   57.   33.78]
#  [26.   64.   31.9 ]]
# The predicted values are [[20.0275028  52.4284976  29.17154972]
#  [15.05015807 50.01990615 38.17119253]
#  [15.25687362 43.9281355  37.04467591]
#  [22.80824325 58.72533159 32.60923326]]
# Diff [[ -4.9724972  -10.5715024    0.88154972]
#  [ 12.55015807  30.01990615   2.51119253]
#  [ -5.74312638 -13.0718645    3.26467591]
#  [ -3.19175675  -5.27466841   0.70923326]]

# %%
# Average training error
dfTrain=y_train-reg.predict(X_train)
print("Average Train error ", np.absolute(dfTrain).mean())

# Average test error
dfTest=y_test-reg.predict(X_test)
print("Average test error ", np.absolute(dfTest).mean())
# Out:
# Average Train error  6.129669513716149
# Average test error  6.135599957973851

# %%
plt.scatter(y_train, reg.predict(X_train))
plt.title('Predictions vs True Values (Training)')
plt.xlabel('True Values')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
plt.scatter(y_test, reg.predict(X_test))
plt.title('Predictions vs True Values (Test)')
plt.xlabel('True Values')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
print(type(x))
print(type(y))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %% [markdown]
# # Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score 

dt_model = DecisionTreeRegressor(random_state=1, splitter='best', max_depth=10, max_features=7, min_samples_leaf=2)
dt_model.fit(X_train, y_train)
y_pred_dt = dt_model.predict(X_test)

# %%
print("Making predictions for the following in train set:")
predicted_values=dt_model.predict(X_train[0:4,:])
true_values=y_train[0:4]
print("True values are ",true_values)
print("The predicted values are", predicted_values)
print("Diff", predicted_values-true_values)


print("Making predictions for the following in testing set:")
predicted_values=dt_model.predict(X_test[0:4,:])
true_values=y_test[0:4]
print("True values are ",true_values)
print("The predicted values are", predicted_values)
print("Diff", predicted_values-true_values)
# Out:
# Making predictions for the following in train set:
# True values are  [[21.   64.   26.28]
#  [24.   75.   36.19]
#  [26.5  68.   35.52]
#  [22.   40.   31.5 ]]
# The predicted values are [[22.75       62.5        26.15      ]
#  [20.5        65.16666667 35.92333333]
#  [24.75       65.75       34.85      ]
#  [19.         33.         36.385     ]]
# Diff [[ 1.75       -1.5        -0.13      ]
#  [-3.5        -9.83333333 -0.26666667]
#  [-1.75       -2.25       -0.67      ]
#  [-3.         -7.          4.885     ]]
# Making predictions for the following in testing set:
# True values are  [[25.   63.   28.29]
#  [ 2.5  20.   35.66]
#  [21.   57.   33.78]
#  [26.   64.   31.9 ]]
# The predicted values are [[19.    33.    36.385]
#  [26.5   68.5   32.91 ]
#  [20.75  50.25  35.72 ]
#  [ 5.    25.    41.41 ]]
# Diff [[ -6.    -30.      8.095]
#  [ 24.     48.5    -2.75 ]
#  [ -0.25   -6.75    1.94 ]
#  [-21.    -39.      9.51 ]]

# %%
# Average training error
dfTrain=y_train-dt_model.predict(X_train)
print("Average Train error ", np.absolute(dfTrain).mean())

# Average test error
dfTest=y_test-dt_model.predict(X_test)
print("Average test error ", np.absolute(dfTest).mean())
# Out:
# Average Train error  2.1636585365853658
# Average test error  8.37994708994709

# %%
print("Model\t\t\t\t RMSE \t\t R2") 
print("""Decision Tree Regressor \t {:.2f} \t\t{:.2f}""".format( np.sqrt(mean_squared_error(y_test, y_pred_dt)), r2_score(y_test, y_pred_dt)))
# Out:
# Model				 RMSE 		 R2
# Decision Tree Regressor 	 13.04 		0.02

# %%
plt.scatter(y_train, dt_model.predict(X_train))
plt.title('Predictions vs True Values (Training)')
plt.xlabel('True Values')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
plt.scatter(y_test, dt_model.predict(X_test))
plt.title('Predictions vs True Values (Test)')
plt.xlabel('True Values')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %% [markdown]
# # Random Forest Regression

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

num_trees=8
rf_model = RandomForestRegressor(random_state=1, max_depth=11, max_samples=82, max_features=7, n_estimators=8)

#Fit RandomForestRegressor model
rf_model.fit(X_train, y_train)
y_pred_rfr = rf_model.predict(X_test) 


print("Making predictions for the following in train set:")
predicted_values=rf_model.predict(X_train[0:4,:])
true_values=y_train[0:4]
print("True values are ",true_values)
print("The predicted values are", predicted_values)
print("Diff", predicted_values-true_values)


print("Making predictions for the following in testing set:")
predicted_values=rf_model.predict(X_test[0:4,:])
true_values=y_test[0:4]
print("True values are ",true_values)
print("The predicted values are", predicted_values)
print("Diff", predicted_values-true_values)

# Average training error
dfTrain=y_train-rf_model.predict(X_train)
print("Average Train error ", np.absolute(dfTrain).mean())

# Average test error
dfTest=y_test-rf_model.predict(X_test)
print("Average test error ", np.absolute(dfTest).mean())
# Out:
# Making predictions for the following in train set:
# True values are  [[21.   64.   26.28]
#  [24.   75.   36.19]
#  [26.5  68.   35.52]
#  [22.   40.   31.5 ]]
# The predicted values are [[18.8125  57.6875  28.62375]
#  [22.6875  71.6875  35.905  ]
#  [25.8125  65.3125  34.59875]
#  [21.9375  43.625   33.0575 ]]
# Diff [[-2.1875  -6.3125   2.34375]
#  [-1.3125  -3.3125  -0.285  ]
#  [-0.6875  -2.6875  -0.92125]
#  [-0.0625   3.625    1.5575 ]]
# Making predictions for the following in testing set:
# True values are  [[25.   63.   28.29]
#  [ 2.5  20.   35.66]
#  [21.   57.   33.78]
#  [26.   64.   31.9 ]]
# The predicted values are [[20.9375 50.375  37.5425]
#  [20.125  53.875  31.57  ]
#  [13.6875 38.75   35.5325]
#  [20.875  58.125  34.5675]]
# Diff [[ -4.0625 -12.625    9.2525]
#  [ 17.625   33.875   -4.09  ]
#  [ -7.3125 -18.25     1.7525]
#  [ -5.125   -5.875    2.6675]]
# Average Train error  2.6687144308943087
# Average test error  6.959047619047618

# %%
print("Model\t\t\t\t RMSE \t\t R2") 
print("""Random Forest Regressor \t {:.2f} \t\t{:.2f}""".format( np.sqrt(mean_squared_error(y_test, y_pred_rfr)), r2_score(y_test, y_pred_rfr)))
# Out:
# Model				 RMSE 		 R2
# Random Forest Regressor 	 9.51 		0.43

# %%
plt.scatter(y_train, rf_model.predict(X_train))
plt.title('Predictions vs True Values (Training)')
plt.xlabel('True Values')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
plt.scatter(y_test, rf_model.predict(X_test))
plt.title('Predictions vs True Values (Test)')
plt.xlabel('True Values')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')
